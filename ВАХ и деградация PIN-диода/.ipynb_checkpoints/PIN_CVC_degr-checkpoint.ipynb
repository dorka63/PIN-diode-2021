# %% [markdown]
# # Доза излучения

# %% [markdown]
# ## 1. Импорт библиотек

# %%
import os
import re
import glob
from collections import defaultdict

import numpy as np
from scipy import interpolate, stats
from scipy.interpolate import UnivariateSpline

from scipy.integrate import trapezoid
from scipy.optimize import curve_fit
from scipy.special import kv


import matplotlib.pyplot as plt
from cycler import cycler
from matplotlib.ticker import FormatStrFormatter, StrMethodFormatter

# Настройки визуализации
#plt.style.use('seaborn-v0_8-paper')
plt.rcParams.update({
    "figure.figsize": (12, 6),
    "figure.dpi": 100,
    "axes.titlesize": 16,
    "axes.labelsize": 14,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "legend.fontsize": 10,
    "lines.linewidth": 1.5,
    "errorbar.capsize": 1.5,
    "image.cmap": "viridis",
    "axes.prop_cycle": cycler(color=plt.cm.plasma(np.linspace(0, 1, 11)))
})

SAVE_FIGS = False
FIG_DPI = 600

# %matplotlib notebook

# %% [markdown]
# $$
# D = \iint \frac{\rho_W}{\rho\cdot V} dV\;dt=\frac{1}{\rho \cdot V}\int_0^{\tau_{max}}\int_0^{\infty}\left[F(E,t)\cdot \frac{0.001E}{[эВ]}\cdot \rho\mu(E)\cdot\int_0^{X_{max}}e^{-\rho\mu(E)x}\;dx\right]\;dE\;dt
# $$

# %% [markdown]
# ## 2. Загрузка данных

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
SPEC1 = np.loadtxt("spectrum-4.txt", skiprows=1)
flux_Be = SPEC1[:, 1] # ph/s/0.1% BW
energy_spec = SPEC1[:, 0]
flux_Be = flux_Be*0.001*energy_spec
plt.figure(figsize=(8,4))
plt.plot(energy_spec,flux_Be)
plt.xlabel("Energy (eV)")
plt.ylabel("Flux(E,I) [ph/s], 1 мА")
plt.title("Спектр после Be")
plt.grid()
plt.show()

print(energy_spec[0],energy_spec[-1])
print(len(energy_spec))
# Out:
# <img src="data:image/png;base64,..." width="800">
# 100.0 50000.0
# 1001

# %%
B_curr2 = np.loadtxt("dosa3.txt")  # mA, мин
mu = np.loadtxt("Si_mu.txt", skiprows=13)  # cm^2/g
mu_si = mu[:,2]

plt.figure(figsize=(8,4))
plt.plot(mu[:,0],mu_si)
plt.xlabel("Energy (eV)")
plt.ylabel("mu [cm^2/gr]")
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ## 3. Aппроксимация тока накопителя $ I(t)$

# %%
print(f"Исходные данные для подгонки:")
print(f"Время: {B_curr2[:, 1]} мин")
print(f"Ток: {B_curr2[:, 0]} мА")

def func(x, a, b):
    return a * np.exp(-b * x) 

popt, pcov = curve_fit(func, B_curr2[:, 1], B_curr2[:, 0])
print(f"Параметры подгонки: a={popt[0]:.2f}, b={popt[1]:.4f}")

t_min = np.linspace(0, 30, 1000)  # мин
beam2_mA = func(t_min, *popt)  # Ток пучка в мА

t_sec = t_min * 60  # секунды
beam2_A = beam2_mA  # mА

print(f"Размер beam2_A: {len(beam2_A)}")


plt.figure(figsize=(8, 4))
plt.plot(t_sec, beam2_A, label='Аппроксимация')
plt.scatter(B_curr2[:, 1] * 60, B_curr2[:, 0], color='red', label='Экспериментальные данные')
plt.xlabel('Time [s]')
plt.ylabel('I_beam [mА]')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# Исходные данные для подгонки:
# Время: [ 0. 15.] мин
# Ток: [5.954 5.534] мА
# Параметры подгонки: a=5.95, b=0.0049
# Размер beam2_A: 1000
# C:\Users\nmurz\AppData\Local\Temp\ipykernel_8544\118383177.py:6: RuntimeWarning: overflow encountered in exp
#   return a * np.exp(-b * x)
# C:\Users\nmurz\anaconda3\Lib\site-packages\scipy\optimize\_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ## 4. Поглощение. Учет толщины диода

# %% [markdown]
# $$
# \int_{0}^{X_{max}} e^{-\mu(E)\rho x}dx = -\frac{1}{\mu(E)\rho}\int_0^{X_{max}}e^{t}dt=-\frac{1}{\mu(E)\rho}\left[e^{-\mu(E)\rho X_{max}}-1\right]=\frac{1}{\mu(E)\rho}\left[1-e^{-\mu(E)\rho X_{max}}\right]
# $$

# %%
rho_si = 2.329  # g/cm^3
def exp_mu(mu_e):
    return (1.-np.exp(-mu_e * rho_si * 0.04))

mu_X = exp_mu(mu_si)
print(f"mu_exp_matrix shape: {mu_X.shape}")

plt.figure(figsize=(8, 4))
plt.plot(mu[:,0], mu_X)
plt.xlabel('Energy [eV]')
plt.ylabel('integrated [a.u]')
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# mu_exp_matrix shape: (999,)
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ## 5. Интегрирование по энергии

# %%
energy_grid = np.linspace(100, 50000, 1001)  # eV

flux_spline = UnivariateSpline(energy_spec, flux_Be, s=0)
mu_spline = UnivariateSpline(mu[:,0], mu_X, s=0)  

flux_grid = flux_spline(energy_grid) 
mu_grid = mu_spline(energy_grid)

flux_grid = flux_grid[:, np.newaxis]        # (N_energy, 1)
mu_grid   = mu_grid[:, np.newaxis]          # (N_energy, 1)
beam_grid = beam2_A[np.newaxis, :]          # (1, N_sec)

Prod_ET = flux_grid * mu_grid * beam_grid  # (N_energy, N_sec)
Prod_T = trapezoid(Prod_ET, energy_grid, axis=0)  # (N_sec,)

plt.figure(figsize=(8,4))
plt.plot(energy_grid, Prod_ET[:, 0], label=f"I = {beam2_A[0]:.2f} mA")
plt.xlabel("Energy [eV]")
plt.ylabel("Flux × mu × I [ph/s]")
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()

plt.figure(figsize=(8,4))
plt.plot(t_sec, Prod_T)
plt.xlabel(" t [s]")
plt.ylabel("integrated {Flux × μ × I}(t) [ph/s*eV]")
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ## 6. Интегрирование по времени

# %%
D = trapezoid(Prod_T, t_sec, axis=0)*1.6e-19/(0.04**2*0.1*rho_si*1e-3) #[eV*ph/kg->J/kg=Gy]
print(f"Доза: {D:.3e} Гр")
# Out:
# Доза: 1.208e+05 Гр

# %% [markdown]
# ## 7. Что попадает на диод

# %% [markdown]
# $$
# D_{max} = \frac{1}{\rho V}\int_0^{\tau_{max}}\int_0^{\infty}F(E,t)\cdot \frac{0.001E}{[эВ]};dE\;dt
# $$

# %%
#mu_new_spline = UnivariateSpline(mu[:,0], mu[:,1], s=0)
#mu_new_grid = rho_si * mu_new_spline(energy_grid)[:, np.newaxis]  # (N_energy,1)


flux_grid = flux_spline(energy_grid)[:, np.newaxis]  # (N_energy,1)
beam_grid = beam2_A[np.newaxis, :]                  # (1, N_sec)

max_Prod_ET = flux_grid * beam_grid   # (N_energy, N_sec)

plt.figure(figsize=(8,4))
plt.plot(energy_grid, max_Prod_ET[:, 0], label=f"I = {beam2_A[0]:.2f} mA")
plt.xlabel("Energy [eV]")
plt.ylabel("Flux × mu × I [ph/s]")
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()

max_Prod_T = trapezoid(max_Prod_ET, energy_grid, axis=0)  # (N_sec,)

plt.figure(figsize=(8,4))
plt.plot(t_sec, max_Prod_T)
plt.xlabel(" t [s]")
plt.ylabel("integrated {Flux × μ × I}(t) [ph/s*eV]")
plt.grid(True, alpha=0.3)
plt.show()


D_max = trapezoid(max_Prod_T, t_sec, axis=0)*1.6e-19/(0.04**2*0.1*rho_si*1e-3) #[eV*ph/kg->J/kg=Gy]
print(f"Максимальная доза: {D_max:.3e} Гр")
# Out:
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# Максимальная доза: 2.110e+05 Гр

# %% [markdown]
# ## 8. Оценка дозы по плотности мощности излучения

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#"Position (mm)"	"Filtered Power (kW/mrad<sup>2</sup>)"

POW = np.loadtxt("power-1.txt", skiprows=1)
Power_Be = POW[:, 1]*1e3/400 # W/mm^2
Pos = POW[:, 0]

plt.figure(figsize=(8,4))
plt.plot(Pos,Power_Be)
plt.xlabel("position [mm]")
plt.ylabel("Power density [W/mm^2], 1 mA")
plt.grid()
plt.show()

D_est = np.max(Power_Be)*0.4*1*np.max(t_sec)/(0.04**2*0.1*rho_si*1e-3) #J/s/mm^2*s*mm^2/kg
print(f"Грубая оценка из плотности мощности: {D_est:.3e} Гр")
# Out:
# <img src="data:image/png;base64,..." width="800">
# Грубая оценка из плотности мощности: 3.038e+06 Гр
